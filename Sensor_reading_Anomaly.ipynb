# %%
import pandas as pd
import numpy as np

# %%
# df=pd.read_parquet('sample_submission.parquet')
# df.head()

# %%
df1=pd.read_parquet('train.parquet')
df1
# Out:
#               Date        X1        X2   X3        X4        X5 target
# 0       2020-12-16  1.518921  5.463154  1.0  2.718282  2.890372      0
# 1       2020-12-16  1.546509  5.458010  1.0  2.718282  2.833213      1
# 2       2020-12-16  1.645427  5.456560  1.0  7.389056  2.890372      1
# 3       2020-12-16  1.652022  5.458479  1.0  2.718282  2.890372      1
# 4       2020-12-16  1.695538  5.466709  1.0  2.718282  2.890372      0
# ...            ...       ...       ...  ...       ...       ...    ...
# 1639419 2024-11-26  1.000000  5.482346  1.0  1.000000  0.000000      0
# 1639420 2024-11-26  1.000000  5.486580  1.0  1.000000  0.000000      0
# 1639421 2024-11-26  1.000000  5.484797  1.0  1.000000  0.000000      0
# 1639422 2024-11-26  1.000000  5.483551  1.0  1.000000  0.000000      0
# 1639423 2024-11-26  1.000000  5.482928  1.0  1.000000  0.000000      0
#
# [1639424 rows x 7 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1639424 entries, 0 to 1639423
# Data columns (total 7 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Date    1639424 non-null  datetime64[ns]
#  1   X1      1639424 non-null  float64
#  2   X2      1639424 non-null  float64
#  3   X3      1639424 non-null  float64
#  4   X4      1639424 non-null  float64
#  5   X5      1639424 non-null  float64
#  6   target  1639424 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 87.6+ MB

# %%
df1['Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['target'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1['target'].value_counts()
# Out:
# target
# 0    1625386
# 1      14038
# Name: count, dtype: int64

# %%
df2=pd.read_parquet('test.parquet')
df2
# Out:
#             ID       Date        X1        X2   X3        X4        X5
# 0            0 2020-12-16  1.685395  5.463917  1.0  7.389056  2.890372
# 1            1 2020-12-16  1.488844  5.454936  1.0  7.389056  2.890372
# 2            2 2020-12-16  1.164160  5.471136  1.0  1.000000  2.890372
# 3            3 2020-12-16  1.000000  5.467385  1.0  1.000000  2.890372
# 4            4 2020-12-16  1.000000  5.453995  1.0  1.000000  2.833213
# ...        ...        ...       ...       ...  ...       ...       ...
# 409851  409851 2024-11-26  1.120752  5.483053  1.0  2.718282  0.000000
# 409852  409852 2024-11-26  1.096365  5.477802  1.0  7.389056  0.000000
# 409853  409853 2024-11-26  1.111822  5.479972  1.0  2.718282  0.000000
# 409854  409854 2024-11-26  1.000000  5.486165  1.0  1.000000  0.000000
# 409855  409855 2024-11-26  1.000000  5.484050  1.0  1.000000  0.000000
#
# [409856 rows x 7 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409856 entries, 0 to 409855
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      409856 non-null  int64
#  1   Date    409856 non-null  datetime64[ns]
#  2   X1      409856 non-null  float64
#  3   X2      409856 non-null  float64
#  4   X3      409856 non-null  float64
#  5   X4      409856 non-null  float64
#  6   X5      409856 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 21.9 MB

# %%
df2['Date'].isnull().sum()
df2['ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
df2=df2.drop(columns='ID')
df2.head()
# Out:
#         Date        X1        X2   X3        X4        X5
# 0 2020-12-16  1.685395  5.463917  1.0  7.389056  2.890372
# 1 2020-12-16  1.488844  5.454936  1.0  7.389056  2.890372
# 2 2020-12-16  1.164160  5.471136  1.0  1.000000  2.890372
# 3 2020-12-16  1.000000  5.467385  1.0  1.000000  2.890372
# 4 2020-12-16  1.000000  5.453995  1.0  1.000000  2.833213

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedKFold
from sklearn.metrics import accuracy_score

# %%
X=df1.drop(columns='target')
X=X.drop(columns='Date')
Y=df1['target']

for col in X.select_dtypes(include=['datetime64[ns]','float64']).columns:
  stand=StandardScaler()
  X[col]=stand.fit_transform(X[[col]])

Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,train_size=0.75,random_state=42)
Xtest.head()
# Out:
#                X1        X2        X3        X4        X5
# 1602121 -0.647186  0.025010 -0.001752 -0.004656  1.346721
# 936861   0.095678  0.500667 -0.001752 -0.004656 -0.909877
# 1037923  1.132706 -0.345338 -0.001752 -0.004656 -0.378653
# 60641    0.948215  0.089632 -0.001752 -0.004656  1.346721
# 94463   -0.417644  0.270890 -0.001752 -0.004656 -0.909877

# %% [markdown]
# ## LogisticRegression

# %%
# model=LogisticRegression()
# model.fit(Xtrain,Ytrain)
# pred=model.predict(Xtest)
# accuracy_score(Ytest,pred)

# %%
# from sklearn.metrics import f1_score
# f0=f1_score(Ytest,pred,pos_label='0')
# f1=f1_score(Ytest,pred,pos_label='1')
# print(f0,f1)

# %%
# from sklearn.metrics import precision_score
# f0=precision_score(Ytest,pred,pos_label='0')
# f1=precision_score(Ytest,pred,pos_label='1')
# print(f0,f1)

# %%
# from sklearn.metrics import recall_score
# f0=recall_score(Ytest,pred,pos_label='0')
# f1=recall_score(Ytest,pred,pos_label='1')
# print(f0,f1)

# %%
# from sklearn.metrics import confusion_matrix
# cm=confusion_matrix(Ytest,pred,labels=['0','1'])
# cm

# %%
# unique_elements, counts = np.unique(pred, return_counts=True)

# print("Unique Elements:", unique_elements)
# print("Counts:", counts)

# %% [markdown]
# ##DecisionTreeClassifier

# %%
# from sklearn.tree import DecisionTreeClassifier
# dtt=DecisionTreeClassifier(random_state=42)
# gridsearch=GridSearchCV(dtt,{'min_samples_split':[2,3,5,10],'min_samples_leaf':[1,2,3,5],'max_depth':[3,5,10,15,20],'criterion':['entropy','gini']},cv=StratifiedKFold(n_splits=5,random_state=42,shuffle=True),scoring='accuracy',n_jobs=-1,verbose=2)
# gridsearch.fit(Xtrain,Ytrain)

# %%
# pred_cv=gridsearch.predict(Xtest)
# accuracy_score(Ytest,pred)

# %%
# from sklearn.metrics import f1_score
# f0=f1_score(Ytest,pred,pos_label='0')
# f1=f1_score(Ytest,pred,pos_label='1')
# print(f0,f1)

# %% [markdown]
# ###Test data

# %%
# stand_test=StandardScaler()
# for col in df2.select_dtypes(include=['datetime64[ns]','float64']).columns:
#   stand_test.fit(df2[[col]])
#   df2[col]=stand_test.transform(df2[[col]])
# df2.head()

# %%
# pred1=model.predict(df2)
# pred1
# # accuracy_score(Ytest,pred)

# %%
# import numpy as np
# unique_elements, counts = np.unique(pred1, return_counts=True)

# print("Unique Elements:", unique_elements)
# print("Counts:", counts)

# %%
# accuracy_score(Ytest,pred1)

# %%
# from sklearn.metrics import f1_score
# f0=f1_score(Ytest,pred1,pos_label='0')
# f1=f1_score(Ytest,pred1,pos_label='1')
# print(f0,f1)

# %%
# from sklearn.metrics import confusion_matrix
# cm=confusion_matrix(Ytest,pred1,labels=['0','1'])
# cm

# %% [markdown]
# ##RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# model=RandomForestClassifier(n_estimators=100,random_state=42)
# gridsearch=GridSearchCV(model,{'max_depth':[15,20,30],'criterion':['entropy','gini']},cv=StratifiedKFold(n_splits=3,random_state=42,shuffle=True),scoring='accuracy',n_jobs=-1,verbose=2)
# gridsearch.fit(Xtrain,Ytrain)

# %% [markdown]
# <!--  -->

# %%
# gridsearch.best_params_

# %%
# ypred=gridsearch.predict(df2)
# accuracy_score(Ytest,ypred)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
num_cols = X.select_dtypes(include=['float64']).columns
num_cols
num_preprocessor = Pipeline(
    steps=[
        ('impute',SimpleImputer(strategy='mean')),
        ('scaler',StandardScaler())
    ]
)
preprocessor = ColumnTransformer(
    transformers=[
        ('num_preprocessor',num_preprocessor,num_cols)
    ]
)

pipeline = Pipeline(
    steps =[
        ('preprocessor',preprocessor),
        ('model',RandomForestClassifier(n_estimators=50,random_state=42,min_samples_split=3))
    ]
)
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,train_size=0.75,random_state=42)

pipeline.fit(Xtrain,Ytrain)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num_preprocessor',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['X1', 'X2', 'X3', 'X4', 'X5'], dtype='object'))])),
#                 ('model',
#                  RandomForestClassifier(n_estimators=50, random_state=42))])

# %%
gridsearch=GridSearchCV(pipeline,{'model__max_depth':[20]},cv=StratifiedKFold(n_splits=3,random_state=42,shuffle=True),scoring='accuracy',n_jobs=-1,verbose=2)
gridsearch.fit(Xtrain,Ytrain)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num_preprocessor',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['X1', 'X2', 'X3', 'X4', 'X5'], dtype='object'))])),
#                                        ('model',
#                                         RandomForestClassifier(n_estimators=50,
# ...

# %%
ypred = pipeline.predict(Xtest)
accuracy_score(ypred,Ytest)
# Out:
# 0.9915458112117427

# %%
# ypred = pipeline.predict(Xtrain)
# accuracy_score(ypred,Ytrain)

# %%
from sklearn.metrics import f1_score
f0=f1_score(Ytest,ypred,pos_label='0')
f1=f1_score(Ytest,ypred,pos_label='1')
print(f0,f1)
# Out:
# 0.9957455063829683 0.3436256866830839

# %%
# df2=df2.drop(columns='ID')
# df2=df2.drop(columns='ID')

stand_test=StandardScaler()
for col in df2.select_dtypes(include=['datetime64[ns]','float64']).columns:
  stand_test.fit(df2[[col]])
  df2[col]=stand_test.transform(df2[[col]])
df2.head()
# Out:
#       Date        X1        X2        X3        X4        X5
# 0 -1.72489  3.930436 -1.804975 -0.001627 -0.004685  1.301413
# 1 -1.72489  2.515746 -2.473169 -0.001627 -0.004685  1.301413
# 2 -1.72489  0.178811 -1.267821 -0.001627 -0.004685  1.301413
# 3 -1.72489 -1.002744 -1.546909 -0.001627 -0.004685  1.301413
# 4 -1.72489 -1.002744 -2.543185 -0.001627 -0.004685  1.257642

# %%
pred1=gridsearch.predict(df2)
pred1
# Out:
# array(['1', '1', '1', ..., '1', '1', '1'], dtype=object)
